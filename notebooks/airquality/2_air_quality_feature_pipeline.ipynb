# %%
import sys
from pathlib import Path
import os

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
from mlfs import config
if os.path.exists(f"{root_dir}/.env"):
    settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/emiljohansson/Documents/KTH/ID2223/Lab_1/mlfs-book
# HopsworksSettings initialized!

# %% [markdown]
# <span style="font-width:bold; font-size: 3rem; color:#333;">- Part 02: Daily Feature Pipeline for Air Quality (aqicn.org) and weather (openmeteo)</span>
#
# ## 🗒️ This notebook is divided into the following sections:
# 1. Download and Parse Data
# 2. Feature Group Insertion
#
#
# __This notebook should be scheduled to run daily__
#
# In the book, we use a GitHub Action stored here:
# [.github/workflows/air-quality-daily.yml](https://github.com/featurestorebook/mlfs-book/blob/main/.github/workflows/air-quality-daily.yml)
#
# However, you are free to use any Python Orchestration tool to schedule this program to run daily.

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import datetime
import time
import requests
import pandas as pd
import hopsworks
from mlfs.airquality import util
from mlfs import config
import json
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌍 Get the Sensor URL, Country, City, Street names from Hopsworks </span>
#
# __Update the values in the cell below.__
#
# __These should be the same values as in notebook 1 - the feature backfill notebook__

# %%
project = hopsworks.login()
fs = project.get_feature_store() 
secrets = hopsworks.get_secrets_api()

# This line will fail if you have not registered the AQICN_API_KEY as a secret in Hopsworks
AQICN_API_KEY = secrets.get_secret("AQICN_API_KEY").value
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
print(location)

country=location['country']
city=location['city']
street=location['street']
aqicn_url=location['aqicn_url']
latitude=location['latitude']
longitude=location['longitude']

today = datetime.date.today()

location_str
# Out:
# 2025-11-13 22:03:19,838 INFO: Initializing external client
# 2025-11-13 22:03:19,839 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-13 22:03:21,508 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1296537
# {'country': 'Germany', 'city': 'Stuttgart', 'street': 'Arnulf-Klett-Platz', 'aqicn_url': 'https://api.waqi.info/feed/@11226', 'latitude': 48.78, 'longitude': 9.18}
# '{"country": "Germany", "city": "Stuttgart", "street": "Arnulf-Klett-Platz", "aqicn_url": "https://api.waqi.info/feed/@11226", "latitude": 48.78, "longitude": 9.18}'

# %% [markdown]
# ### <span style="color:#ff5f27;"> 🔮 Get references to the Feature Groups </span>

# %%
# Retrieve feature groups
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=2,
)
weather_fg = fs.get_feature_group(
    name='weather',
    version=2,
)

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌫 Retrieve Today's Air Quality data (PM2.5) from the AQI API</span>

# %%
import requests
import pandas as pd

aq_today_df = util.get_pm25(aqicn_url, country, city, street, today, AQICN_API_KEY)
aq_today_df
# Out:
#    pm25  country       city              street       date  \
# 0  74.0  Germany  Stuttgart  Arnulf-Klett-Platz 2025-11-13
#
#                                  url
# 0  https://api.waqi.info/feed/@11226

# %%
aq_today_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   pm25     1 non-null      float32
#  1   country  1 non-null      object
#  2   city     1 non-null      object
#  3   street   1 non-null      object
#  4   date     1 non-null      datetime64[ns]
#  5   url      1 non-null      object
# dtypes: datetime64[ns](1), float32(1), object(4)
# memory usage: 172.0+ bytes

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌦 Get Weather Forecast data</span>

# %%
hourly_df = util.get_hourly_weather_forecast(city, latitude, longitude)
hourly_df = hourly_df.set_index('date')

# We will only make 1 daily prediction, so we will replace the hourly forecasts with a single daily forecast
# We only want the daily weather data, so only get weather at 12:00
daily_df = hourly_df.between_time('11:59', '12:01')
daily_df = daily_df.reset_index()
daily_df['date'] = pd.to_datetime(daily_df['date']).dt.date
daily_df['date'] = pd.to_datetime(daily_df['date'])
daily_df['city'] = city
daily_df
# Out:
# Coordinates 48.75°N 9.25°E
# Elevation 255.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#         date  temperature_2m_mean  precipitation_sum  wind_speed_10m_max  \
# 0 2025-11-13            18.049999                0.0            7.928178
# 1 2025-11-14            17.350000                0.0            4.680000
# 2 2025-11-15            15.300000                0.0            2.520000
# 3 2025-11-16            14.050000                0.0            2.545584
# 4 2025-11-17             6.550000                0.0           15.042659
# 5 2025-11-18             5.150000                0.0            1.609969
# 6 2025-11-19             6.100000                0.0           19.008545
#
#    wind_direction_10m_dominant       city
# 0                   182.602509  Stuttgart
# 1                   112.619911  Stuttgart
# 2                    90.000000  Stuttgart
# 3                    81.869987  Stuttgart
# 4                   338.962402  Stuttgart
# 5                   153.435013  Stuttgart
# 6                   232.695969  Stuttgart

# %%
daily_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         7 non-null      datetime64[ns]
#  1   temperature_2m_mean          7 non-null      float32
#  2   precipitation_sum            7 non-null      float32
#  3   wind_speed_10m_max           7 non-null      float32
#  4   wind_direction_10m_dominant  7 non-null      float32
#  5   city                         7 non-null      object
# dtypes: datetime64[ns](1), float32(4), object(1)
# memory usage: 352.0+ bytes

# %% [markdown]
# ## <span style="color:#ff5f27;">⬆️ Uploading new data to the Feature Store</span>

# %%
# Insert new data
air_quality_fg.insert(aq_today_df)
# Out:
# 2025-11-13 22:03:25,589 INFO: 	1 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1296537/fs/1284170/fg/1706364
# Uploading Dataframe: 100.00% |██████████| Rows 1/1 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: air_quality_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1296537/jobs/named/air_quality_1_offline_fg_materialization/executions
# (Job('air_quality_1_offline_fg_materialization', 'SPARK'),
#  {
#    "success": true,
#    "results": [
#      {
#        "success": true,
#        "expectation_config": {
#          "expectation_type": "expect_column_min_to_be_between",
#          "kwargs": {
#            "column": "pm25",
#            "min_value": -0.1,
#            "max_value": 500.0,
#            "strict_min": true
#          },
#          "meta": {
#            "expectationId": 750626
#          }
#        },
#        "result": {
#          "observed_value": 74.0,
#          "element_count": 1,
#          "missing_count": null,
#          "missing_percent": null
#        },
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2025-11-13T09:03:25.000589Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      }
#    ],
#    "evaluation_parameters": {},
#    "statistics": {
#      "evaluated_expectations": 1,
#      "successful_expectations": 1,
#      "unsuccessful_expectations": 0,
#      "success_percent": 100.0
#    },
#    "meta": {
#      "great_expectations_version": "0.18.12",
#      "expectation_suite_name": "aq_expectation_suite",
#      "run_id": {
#        "run_name": null,
#        "run_time": "2025-11-13T22:03:25.589327+01:00"
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "322c7112-c0d4-11f0-9629-daa6cdb91d04"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
#      "validation_time": "20251113T210325.589043Z",
#      "expectation_suite_meta": {
#        "great_expectations_version": "0.18.12"
#      }
#    }
#  })

# %%
# Insert new data
weather_fg.insert(daily_df, wait=True)
# Out:
# 2025-11-13 22:03:39,399 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1296537/fs/1284170/fg/1703322
# Uploading Dataframe: 100.00% |██████████| Rows 7/7 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: weather_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1296537/jobs/named/weather_1_offline_fg_materialization/executions
# 2025-11-13 22:03:55,833 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-11-13 22:03:59,024 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Insert new data
# ----> 2 weather_fg.insert(daily_df, wait=True)
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hsfs/feature_group.py:3153, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, wait, transformation_context, transform)
#    3150 if not self._id and self._offline_backfill_every_hr is not None:
#    3151     write_options["offline_backfill_every_hr"] = self._offline_backfill_every_hr
# -> 3153 job, ge_report = self._feature_group_engine.insert(
#    3154     self,
#    3155     feature_dataframe=feature_dataframe,
#    3156     overwrite=overwrite,
#    3157     operation=operation,
#    3158     storage=storage.lower() if storage is not None else None,
#    3159     write_options=write_options,
#    3160     validation_options={"save_report": True, **validation_options},
#    3161     transformation_context=transformation_context,
#    3162     transform=transform,
#    3163 )
#    3165 if engine.get_type().startswith("spark") and not self.stream:
#    3166     # Also, only compute statistics if stream is False.
#    3167     # if True, the backfill job has not been triggered and the data has not been inserted (it's in Kafka)
#    3168     self.compute_statistics()
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hsfs/core/feature_group_engine.py:245, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options, transformation_context, transform)
#     241 if overwrite:
#     242     self._feature_group_api.delete_content(feature_group)
#     244 return (
# --> 245     engine.get_instance().save_dataframe(
#     246         feature_group,
#     247         feature_dataframe,
#     248         "bulk_insert" if overwrite else operation,
#     249         feature_group.online_enabled,
#     250         storage,
#     251         offline_write_options,
#     252         online_write_options,
#     253     ),
#     254     ge_report,
#     255 )
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hsfs/engine/python.py:819, in Engine.save_dataframe(self, feature_group, dataframe, operation, online_enabled, storage, offline_write_options, online_write_options, validation_id)
#     804 def save_dataframe(
#     805     self,
#     806     feature_group: FeatureGroup,
#    (...)
#     813     validation_id: Optional[int] = None,
#     814 ) -> Optional[job.Job]:
#     815     if (
#     816         hasattr(feature_group, "EXTERNAL_FEATURE_GROUP")
#     817         and feature_group.online_enabled
#     818     ) or feature_group.stream:
# --> 819         return self._write_dataframe_kafka(
#     820             feature_group, dataframe, offline_write_options
#     821         )
#     822     else:
#     823         # for backwards compatibility
#     824         return self.legacy_save_dataframe(
#     825             feature_group,
#     826             dataframe,
#    (...)
#     832             validation_id,
#     833         )
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hsfs/engine/python.py:1605, in Engine._write_dataframe_kafka(self, feature_group, dataframe, offline_write_options)
#    1603         initial_check_point = ""
#    1604     # provide the initial_check_point as it will reduce the read amplification of materialization job
# -> 1605     feature_group.materialization_job.run(
#    1606         args=feature_group.materialization_job.config.get("defaultArgs", "")
#    1607         + (
#    1608             f" -initialCheckPointString {initial_check_point}"
#    1609             if initial_check_point
#    1610             else ""
#    1611         ),
#    1612         await_termination=offline_write_options.get("wait_for_job", False),
#    1613     )
#    1615 # wait for online ingestion
#    1616 if feature_group.online_enabled and offline_write_options.get(
#    1617     "wait_for_online_ingestion", False
#    1618 ):
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hopsworks_common/usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hopsworks_common/job.py:186, in Job.run(self, args, await_termination)
#     182 print(
#     183     f"Job started successfully, you can follow the progress at \n{execution.get_url()}"
#     184 )
#     185 if await_termination:
# --> 186     return self._execution_engine.wait_until_finished(self, execution)
#     187 else:
#     188     return execution
#
# File ~/opt/anaconda3/envs/aq/lib/python3.10/site-packages/hopsworks_common/engine/execution_engine.py:126, in ExecutionEngine.wait_until_finished(self, job, execution, timeout)
#     124     self._log.info("The waiting timeout was exceeded.")
#     125     return updated_execution
# --> 126 time.sleep(MAX_LAG)
#     127 updated_execution = self._execution_api._get(job, execution.id)
#     128 if execution_state != updated_execution.state:
#
# KeyboardInterrupt:

# %% [markdown]
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 03: Training Pipeline
#  </span>
#
# In the following notebook you will read from a feature group and create training dataset within the feature store
